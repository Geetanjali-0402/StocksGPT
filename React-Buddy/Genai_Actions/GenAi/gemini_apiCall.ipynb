# %%
# %pip install -U -q google-generativeai
# %pip install python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pathlib
import textwrap
import time

import google.generativeai as genai

from IPython import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Import required libraries
import os
from dotenv import load_dotenv
import requests

# Load environment variables from .env file
load_dotenv()

# Access the GOOGLE_API_KEY environment variable
google_api_key = os.getenv('GOOGLE_API_KEY')

# Just for testing: print the API key to ensure it's loaded correctly (remove in production)
print('Your Google API Key:', google_api_key)

# Example usage of the API key (e.g., making a request to a Google API)
# Replace `some_api_endpoint` with an actual endpoint you intend to use
# Out:
# Your Google API Key: AIzaSyDasTROnctLMe1uJny-ywuM57HX4p4FBBY

# %%
genai.configure(api_key=google_api_key)

# %%
def multiply(a:float, b:float):
    """returns a * b."""
    return a*b

model = genai.GenerativeModel(model_name='gemini-1.0-pro',
                              tools=[multiply])

model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.0-pro',
#     generation_config={},
#     safety_settings={},
#     tools=<google.generativeai.types.content_types.FunctionLibrary object at 0x0000024C6155A2A0>,
#     system_instruction=None,
#     cached_content=None
# )

# %%
chat = model.start_chat(enable_automatic_function_calling=True)

# %%
response = chat.send_message('I have 57 cats, each owns 44 mittens, how many mittens is that in total?')
response.text
# Out:
# 'There are 2,508 mittens in total.'

# %%
# Import required libraries
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Access the GOOGLE_API_KEY environment variable
google_api_key = os.getenv('GOOGLE_API_KEY')

if google_api_key is None:
    raise ValueError("No GOOGLE_API_KEY found. Please set the environment variable.")

# Configure the genai library with the API key
genai.configure(api_key=google_api_key)

# Example usage of the API key (if needed for further code)
print('Your Google API Key:', google_api_key)
# Out:
# Your Google API Key: AIzaSyDasTROnctLMe1uJny-ywuM57HX4p4FBBY

# %%
import os

def find_file(filename, directory):
    for root, dirs, files in os.walk(directory):
        if filename in files:
            return os.path.join(root, filename)
    return None

def read_file(filepath):
    with open(filepath, 'r') as file:
        return file.read()

directory_path = "C:/Users/DGASERLAP177/Documents/GitHub/StocksGPT"
file_to_find = 'Login.tsx'

# Find the file
file_path = find_file(file_to_find, directory_path)

if file_path:
    # Read the file contents
    file_contents = read_file(file_path)
    print("File contents successfully read.")
else:
    print("File not found.")

# The variable file_contents now holds the contents of app.ts file

print(file_contents)
# Out:
# File contents successfully read.
# import React, { useEffect, useState } from "react";
# import {
#   Alert,
#   Row,
#   Col,
#   Form,
#   Label,
#   Button,
#   UncontrolledTooltip,
# } from "reactstrap";
#
# //Social Media Imports
# // import { GoogleLogin } from "react-google-login";
# import FacebookLogin from "react-facebook-login/dist/facebook-login-render-props";
#
# // router
# import { Link, Navigate, useLocation, useNavigate } from "react-router-dom";
#
# // validations
# import { yupResolver } from "@hookform/resolvers/yup";
# import * as yup from "yup";
# import { useForm } from "react-hook-form";
#
# // config
# import config from "../../config";
#
# // hooks
# import { useProfile, useRedux } from "../../hooks/index";
# import { createSelector } from "reselect";
# //actions
# import { loginUser, socialLogin } from "../../redux/auth/loginNode/actions";
#
# // components
# import NonAuthLayoutWrapper from "../../components/NonAutnLayoutWrapper";
# ...

# %%
# !pip install babel
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB 326.8 kB/s eta 0:00:30
#     --------------------------------------- 0.1/9.6 MB 871.5 kB/s eta 0:00:11
#    - -------------------------------------- 0.3/9.6 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/9.6 MB 2.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/9.6 MB 4.2 MB/s eta 0:00:03
#    -------- ------------------------------- 2.0/9.6 MB 6.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.3/9.6 MB 6.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.7/9.6 MB 6.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/9.6 MB 6.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/9.6 MB 6.5 MB/s eta 0:00:02
# ...

# %%
# Out:
#   Cell In[22], line 1
#     const fs = require('fs');
#           ^
# SyntaxError: invalid syntax

# %%
print(routes_path)
# Out:
# The only actions dispatched from the code are:
# - `loginUser`
# - `socialLogin`

# %%
processed_list = [line.replace('-', '').strip() for line in routes_path.split('\n') if line.strip()]

# Output the processed list
print(processed_list)
# Out:
# ['The only actions dispatched from the code are:', '`loginUser`', '`socialLogin`']

# %%
import os

def find_file_upwards(starting_path, target_filename):
    # Set the current path to the starting path
    current_path = starting_path

    while True:
        # Check if the target file exists in the current directory
        for root, dirs, files in os.walk(current_path):
            if target_filename in files:
                return os.path.join(root, target_filename)
        
        # Move up one directory level
        parent_path = os.path.dirname(current_path)
        
        # If we have reached the root directory, stop searching
        if parent_path == current_path:
            break
        
        current_path = parent_path

    # Return None if the file was not found
    return None

# Example usage
starting_path = "C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\pages\\Authentication" # Starting from the current directory
target_filename = "actions.ts"  # The name of the file to search for

found_file_path = find_file_upwards(starting_path, target_filename)

if found_file_path:
    print(f"File found: {found_file_path}")
    # You can also perform additional actions with the found file path
else:
    print("File not found")
# Out:
# File found: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\redux\actions.ts

# %%
def read_file(found_file_path):
    with open(found_file_path, 'r') as file:
        return file.read()

file_contents = read_file(found_file_path)
print(file_contents)
# Out:
# //auth
# export * from "./auth/forgetpwd/actions";
# //export * from "./auth/login/actions";
# export * from "./auth/loginNode/actions";
# export * from "./auth/register/actions";
#
# // layout
# export * from "./layout/actions";
#
# // profile
# export * from "./profile/actions";
#
#
# // settings
# export * from "./settings/actions";
#
# // stockChats
# export * from "./stockChats/actions";

# %%
Redux_Actions_Response = chat.send_message('Find the source of all the actions called in the exports. no hyphen, only the source paths'+file_contents)
Redux_Actions=Redux_Actions_Response.text

# %%
print(Redux_Actions)
# Out:
# - `./auth/forgetpwd/actions`
# - `./auth/loginNode/actions`
# - `./auth/register/actions`
# - `./layout/actions`
# - `./profile/actions`
# - `./settings/actions`
# - `./stockChats/actions`

# %%
import re

def extract_source_paths(text):
    # Split the text by new lines
    lines = text.strip().split('\n')
    
    # Use a regular expression to clean each line
    source_paths = [re.sub(r'[-`*\s]', '', line) for line in lines if line.strip().startswith('-')]
    
    return source_paths


# Extract and print the source paths
source_paths = extract_source_paths(Redux_Actions)
for path in source_paths:
    print(path)
# Out:
# ./auth/forgetpwd/actions
# ./auth/loginNode/actions
# ./auth/register/actions
# ./layout/actions
# ./profile/actions
# ./settings/actions
# ./stockChats/actions

# %%
import os

def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            return file.read()
    except Exception as e:
        return f"Failed to read {file_path}: {e}"

def find_real_paths(base_folder, source_paths):
    real_paths = []
    for path in source_paths:
        # Append .ts to each path
        path_with_extension = path + ".ts"
        real_path = os.path.abspath(os.path.join(base_folder, path_with_extension))
        if os.path.exists(real_path):
            real_paths.append(real_path)
        else:
            real_paths.append(f"Path does not exist: {real_path}")
    return real_paths

# The provided list of source paths
source_paths = [
    "./auth/forgetpwd/actions",
    "./auth/loginNode/actions",
    "./auth/register/actions",
    "./layout/actions",
    "./profile/actions",
    "./settings/actions",
    "./stockChats/actions"
]

# Assuming the base folder is the specified directory
base_folder = "C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux"

# Find the real paths
real_paths = find_real_paths(base_folder, source_paths)

# Read and print the contents of each file
for path in real_paths:
    if os.path.exists(path):
        file_contents_Indi_Actions = read_file(path)
        print(f"Contents of {path}:\n{file_contents_Indi_Actions}\n{'-'*60}\n")
    else:
        print(path)  # This will print the "Path does not exist" messages
# Out:
# Contents of C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\redux\auth\forgetpwd\actions.ts:
# import { AuthForgetPassActionTypes } from "./types";
#
# // common success
# export const authForgetPassApiResponseSuccess = (
#   actionType: string,
#   data: any
# ) => ({
#   type: AuthForgetPassActionTypes.API_RESPONSE_SUCCESS,
#   payload: { actionType, data },
# });
# // common error
# export const authForgetPassApiResponseError = (
#   actionType: string,
#   error: string
# ) => ({
#   type: AuthForgetPassActionTypes.API_RESPONSE_ERROR,
#   payload: { actionType, error },
# });
#
# export const userForgetPassword = (user: any) => {
#   return {
#     type: AuthForgetPassActionTypes.FORGET_PASSWORD,
#     payload: user,
#   };
# };
#
# export const userChangePassword = (newPassword: any) => {
#   return {
#     type: AuthForgetPassActionTypes.CHANGE_PASSWORD,
#     payload: newPassword,
#   };
# };
#
# ------------------------------------------------------------
#
# ...

# %%
import re

# Create a regex pattern to match action type constants (uppercase words with underscores)
pattern = re.compile(r'\b[A-Z_]+\b')

# Define the file paths with double backslashes
file_paths = [
    r'C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\forgetpwd\\actions.ts',
    r'C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\loginNode\\actions.ts',
    r'C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\register\\actions.ts',
    r'C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\layout\\actions.ts',
    r'C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\profile\\actions.ts',
    r'C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\settings\\actions.ts',
    r'C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\stockChats\\actions.ts'
]

# Function to find and print the action types in the files
def find_action_types(file_paths, pattern):
    for file_path in file_paths:
        with open(file_path, 'r') as file:
            content = file.read()
            matches = pattern.findall(content)
            if matches:
                print(f"Matches in {file_path}:")
                for match in matches:
                    print(f"  {match}")

# Call the function
find_action_types(file_paths, pattern)
# Out:
# Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\forgetpwd\\actions.ts:
#   API_RESPONSE_SUCCESS
#   API_RESPONSE_ERROR
#   FORGET_PASSWORD
#   CHANGE_PASSWORD
# Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\loginNode\\actions.ts:
#   API_RESPONSE_SUCCESS
#   API_RESPONSE_ERROR
#   LOGIN_USER
#   LOGOUT_USER
#   SOCIAL_LOGIN
#   GOOGLE_VERIFY
# Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\register\\actions.ts:
#   API_RESPONSE_SUCCESS
#   API_RESPONSE_ERROR
#   REGISTER_USER
# Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\layout\\actions.ts:
#   CHANGE_TAB
#   CHANGE_LAYOUT_MODE
# Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\profile\\actions.ts:
#   API_RESPONSE_SUCCESS
#   API_RESPONSE_ERROR
#   GET_PROFILE_DETAILS
#   UPDATE_PROFILE_DETAILS
# ...

# %%
import re

# Input text
text = """
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\forgetpwd\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  FORGET_PASSWORD
  CHANGE_PASSWORD
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\loginNode\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  LOGIN_USER
  LOGOUT_USER
  SOCIAL_LOGIN
  GOOGLE_VERIFY
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\register\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  REGISTER_USER
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\layout\\actions.ts:
  CHANGE_TAB
  CHANGE_LAYOUT_MODE
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\profile\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  GET_PROFILE_DETAILS
  UPDATE_PROFILE_DETAILS
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\settings\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  GET_USER_SETTINGS
  UPDATE_USER_SETTINGS
  UPDATE_ALL_SETTINGS
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\stockChats\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  GET_STOCK_CHAT_TITLES
  ADD_NEW_CHAT
  DELETE_STOCK_CHAT
  GET_STOCK_CHAT_MESSAGES
  SEND_USER_MESSAGE
  RECEIVE_BOT_MESSAGE
  SET_SHOW_WELCOME_SCREEN_FLAG
  CHANGE_SELECTED_STOCK_CHAT
"""

# Regular expression to match action names (uppercase words with at least 2 characters)
pattern = r'\b[A-Z_]{2,}\b'

# Find all matches
matches = re.findall(pattern, text)

# Print the list of action names
print(matches)
# Out:
# ['API_RESPONSE_SUCCESS', 'API_RESPONSE_ERROR', 'FORGET_PASSWORD', 'CHANGE_PASSWORD', 'API_RESPONSE_SUCCESS', 'API_RESPONSE_ERROR', 'LOGIN_USER', 'LOGOUT_USER', 'SOCIAL_LOGIN', 'GOOGLE_VERIFY', 'API_RESPONSE_SUCCESS', 'API_RESPONSE_ERROR', 'REGISTER_USER', 'CHANGE_TAB', 'CHANGE_LAYOUT_MODE', 'API_RESPONSE_SUCCESS', 'API_RESPONSE_ERROR', 'GET_PROFILE_DETAILS', 'UPDATE_PROFILE_DETAILS', 'API_RESPONSE_SUCCESS', 'API_RESPONSE_ERROR', 'GET_USER_SETTINGS', 'UPDATE_USER_SETTINGS', 'UPDATE_ALL_SETTINGS', 'API_RESPONSE_SUCCESS', 'API_RESPONSE_ERROR', 'GET_STOCK_CHAT_TITLES', 'ADD_NEW_CHAT', 'DELETE_STOCK_CHAT', 'GET_STOCK_CHAT_MESSAGES', 'SEND_USER_MESSAGE', 'RECEIVE_BOT_MESSAGE', 'SET_SHOW_WELCOME_SCREEN_FLAG', 'CHANGE_SELECTED_STOCK_CHAT']

# %%
import re
from collections import defaultdict

# Define the base path with a placeholder
base_path = r'C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\{}\\reducer.ts'

# List of specific subdirectory names
subdirs = [
    'auth\\forgetpwd',
    'auth\\loginNode',
    'auth\\register',
    'layout',
    'profile',
    'settings',
    'stockChats'
]

# Create a regex pattern to match lines with action types
pattern = re.compile(r'\b[A-Z_]+\b')

# Define the output text
output_text = """
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\forgetpwd\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  FORGET_PASSWORD
  CHANGE_PASSWORD
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\loginNode\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  LOGIN_USER
  LOGOUT_USER
  SOCIAL_LOGIN
  GOOGLE_VERIFY
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\auth\\register\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  REGISTER_USER
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\layout\\actions.ts:
  CHANGE_TAB
  CHANGE_LAYOUT_MODE
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\profile\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  GET_PROFILE_DETAILS
  UPDATE_PROFILE_DETAILS
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\settings\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  GET_USER_SETTINGS
  UPDATE_USER_SETTINGS
  UPDATE_ALL_SETTINGS
Matches in C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\stockChats\\actions.ts:
  API_RESPONSE_SUCCESS
  API_RESPONSE_ERROR
  GET_STOCK_CHAT_TITLES
  ADD_NEW_CHAT
  DELETE_STOCK_CHAT
  GET_STOCK_CHAT_MESSAGES
  SEND_USER_MESSAGE
  RECEIVE_BOT_MESSAGE
  SET_SHOW_WELCOME_SCREEN_FLAG
  CHANGE_SELECTED_STOCK_CHAT
"""

# Dictionary to store counts of action types for each file
action_counts = defaultdict(lambda: defaultdict(int))

# Split the output text into lines and process each line
lines = output_text.splitlines()
current_file = None

for line in lines:
    # Check if the line indicates a file path
    file_match = re.match(r'Matches in (C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\[\w\\]+\\actions\.ts):', line)
    if file_match:
        current_file = file_match.group(1).replace('actions.ts', 'reducer.ts')
    elif current_file:
        # Match action types in the line
        action_matches = pattern.findall(line)
        for action in action_matches:
            action_counts[current_file][action] += 1

# Print the results
for file_path, counts in action_counts.items():
    print(f"Counts in {file_path}:")
    for action_type, count in counts.items():
        print(f"  {action_type}: {count}")
# Out:
# Counts in Matches in C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\redux\auth\forgetpwd\reducer.ts::
#   API_RESPONSE_SUCCESS: 6
#   API_RESPONSE_ERROR: 6
#   FORGET_PASSWORD: 1
#   CHANGE_PASSWORD: 1
#   Matches in C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\redux\auth\loginNode\actions.ts:: 1
#   LOGIN_USER: 1
#   LOGOUT_USER: 1
#   SOCIAL_LOGIN: 1
#   GOOGLE_VERIFY: 1
#   Matches in C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\redux\auth\register\actions.ts:: 1
#   REGISTER_USER: 1
#   Matches in C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\redux\layout\actions.ts:: 1
#   CHANGE_TAB: 1
#   CHANGE_LAYOUT_MODE: 1
#   Matches in C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\redux\profile\actions.ts:: 1
#   GET_PROFILE_DETAILS: 1
#   UPDATE_PROFILE_DETAILS: 1
#   Matches in C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\redux\settings\actions.ts:: 1
#   GET_USER_SETTINGS: 1
#   UPDATE_USER_SETTINGS: 1
#   UPDATE_ALL_SETTINGS: 1
# ...

# %%
import os

# Navigate back to the parent directory
current_directory = "C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\redux\\stockChats\\reducer.ts"
parent_directory = os.path.abspath(os.path.join(current_directory, os.pardir))

# Saga file path
saga_file = "saga.ts"

# Function to check if the keyword exists in the saga file
def keyword_in_saga(keyword, saga_file):
    with open(saga_file, 'r') as f:
        content = f.read()
        if keyword in content:
            return True
    return False


# Iterate over keywords and check if they exist in the saga file
for keyword in filtered_keywords:
    if keyword_in_saga(keyword, os.path.join(parent_directory, saga_file)):
        print(f"Keyword '{keyword}' found in saga.ts file")
# Out:
# Keyword 'GET_STOCK_CHAT_TITLES' found in saga.ts file
# Keyword 'ADD_NEW_CHAT' found in saga.ts file
# Keyword 'GET_STOCK_CHAT_MESSAGES' found in saga.ts file
# Keyword 'SEND_USER_MESSAGE' found in saga.ts file
# Keyword 'DELETE_STOCK_CHAT' found in saga.ts file

# %%
import json

# Given JSON input


# Parse JSON input
data = routes_path

# Create dictionary to hold structured data
structured_data = {}

# Extract component names and actions
for component, actions in data.items():
    structured_data[component] = actions

# Write structured data to a JSON file
with open("structured_data.json", "w") as json_file:
    json.dump(structured_data, json_file, indent=2)

print("JSON data has been written to structured_data.json")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 13
#      10 structured_data = {}
#      12 # Extract component names and actions
# ---> 13 for component, actions in data.items():
#      14     structured_data[component] = actions
#      16 # Write structured data to a JSON file
#
# AttributeError: 'str' object has no attribute 'items'

# %%
# Function to open and read a file
def open_file(file_path):
    try:
        with open(file_path, 'r') as file:
            contents = file.read()
            print(contents)
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
file_path = "C:/Users/DGASERLAP177/Documents/GitHub/StocksGPT/node_modules/reactstrap/es/Alert"
open_file(file_path)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[31], line 6
#       1 import json
#       5 # Parse JSON input
# ----> 6 data = json.loads(routes_path)
#       8 # Create dictionary to hold structured data
#       9 structured_data = {}
#
# File c:\Users\DGASERLAP177\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
import os
import json

def fileNavigator(FolderPathPython, JsRelativePath):
    # Extracting the number of upward folders and the relative folder path from JsRelativePath
    split_path = JsRelativePath.split('/')
    NoOfUpFolders = sum(1 for part in split_path if part == '..')
    JsRelativeFolderPath = '/'.join(part for part in split_path if part not in ['..', '.'])
    
    # Converting JsRelativeFolderPath to Python relative folder path
    PyRelativeFolderPath = JsRelativeFolderPath.replace('/', '\\')
    
    # Splitting FolderPathPython into components
    folder_components = FolderPathPython.split('\\')
    
    # Trimming the folder path based on NoOfUpFolders
    if NoOfUpFolders > 0:
        TrimmedFolderPathPython = '\\'.join(folder_components[:-NoOfUpFolders])
    else:
        TrimmedFolderPathPython = FolderPathPython
    
    # Constructing the new file path
    NewFilePath = os.path.join(TrimmedFolderPathPython, PyRelativeFolderPath)
    
    return NewFilePath

# Function to read JS relative paths from a JSON file and process each
def processPathsFromJson(jsonFilePath, FolderPathPython):
    # Read the JSON file
    with open(jsonFilePath, 'r') as file:
        jsPaths = json.load(file)
    
    # Process each component's JS relative path and print the new file path
    for component in jsPaths["components"]:
        name = component["name"]
        JsRelativePath = component["path"].strip('`')
        new_file_path = fileNavigator(FolderPathPython, JsRelativePath)
        new_file_path_with_extension = new_file_path + '.tsx'
        print(f"Component Name: {name} -> New file path: {new_file_path_with_extension}")

# Example usage
FolderPathPython = "C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\pages\\Authentication"
jsonFilePath = "components_login.json"  # Assuming this file contains the JSON array of paths

processPathsFromJson(jsonFilePath, FolderPathPython)
# Out:
# Component Name: **Loader** -> New file path: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\Loader.tsx
# Component Name: **AuthHeader** -> New file path: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\AuthHeader.tsx
# Component Name: **FormInput** -> New file path: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\FormInput.tsx
# Component Name: **NonAuthLayoutWrapper** -> New file path: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\NonAutnLayoutWrapper.tsx

# %%
import os
import json

def fileNavigator(FolderPathPython, JsRelativePath):
    # Extracting the number of upward folders and the relative folder path from JsRelativePath
    split_path = JsRelativePath.split('/')
    NoOfUpFolders = sum(1 for part in split_path if part == '..')
    JsRelativeFolderPath = '/'.join(part for part in split_path if part not in ['..', '.'])
    
    # Converting JsRelativeFolderPath to Python relative folder path
    PyRelativeFolderPath = JsRelativeFolderPath.replace('/', '\\')
    
    # Splitting FolderPathPython into components
    folder_components = FolderPathPython.split('\\')
    
    # Trimming the folder path based on NoOfUpFolders
    if NoOfUpFolders > 0:
        TrimmedFolderPathPython = '\\'.join(folder_components[:-NoOfUpFolders])
    else:
        TrimmedFolderPathPython = FolderPathPython
    
    # Constructing the new file path
    NewFilePath = os.path.join(TrimmedFolderPathPython, PyRelativeFolderPath)
    
    return NewFilePath

# Function to read JS relative paths from a JSON file and process each
def processPathsFromJson(jsonFilePath, FolderPathPython):
    # Read the JSON file
    with open(jsonFilePath, 'r') as file:
        jsPaths = json.load(file)
    
    # Initialize an empty dictionary to store the new file paths
    file_paths_dict = {}

    # Process each component's JS relative path and store the new file path in the dictionary
    for component in jsPaths["components"]:
        name = component["name"]
        JsRelativePath = component["path"].strip('`')
        new_file_path = fileNavigator(FolderPathPython, JsRelativePath)
        new_file_path_with_extension = new_file_path + '.tsx'
        # Store in dictionary
        file_paths_dict[name] = new_file_path_with_extension

    return file_paths_dict

# Example usage
FolderPathPython = "C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\pages\\Authentication"
jsonFilePath = "components_login.json"  # Assuming this file contains the JSON array of paths

# Process paths and store the result in a dictionary
result = processPathsFromJson(jsonFilePath, FolderPathPython)

# Print the result dictionary
print("Dictionary of new file paths:")
for key, value in result.items():
    print(f"{key}: {value}")
# Out:
# Dictionary of new file paths:
# **Loader**: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\Loader.tsx
# **AuthHeader**: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\AuthHeader.tsx
# **FormInput**: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\FormInput.tsx
# **NonAuthLayoutWrapper**: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\NonAutnLayoutWrapper.tsx

# %%
import os
import json

def fileNavigator(FolderPathPython, JsRelativePath):
    # Extracting the number of upward folders and the relative folder path from JsRelativePath
    split_path = JsRelativePath.split('/')
    NoOfUpFolders = sum(1 for part in split_path if part == '..')
    JsRelativeFolderPath = '/'.join(part for part in split_path if part not in ['..', '.'])
    
    # Converting JsRelativeFolderPath to Python relative folder path
    PyRelativeFolderPath = JsRelativeFolderPath.replace('/', '\\')
    
    # Splitting FolderPathPython into components
    folder_components = FolderPathPython.split('\\')
    
    # Trimming the folder path based on NoOfUpFolders
    if NoOfUpFolders > 0:
        TrimmedFolderPathPython = '\\'.join(folder_components[:-NoOfUpFolders])
    else:
        TrimmedFolderPathPython = FolderPathPython
    
    # Constructing the new file path
    NewFilePath = os.path.join(TrimmedFolderPathPython, PyRelativeFolderPath)
    
    return NewFilePath

# Function to read JS relative paths from a JSON file and process each
def processPathsFromJson(jsonFilePath, FolderPathPython):
    # Read the JSON file
    with open(jsonFilePath, 'r') as file:
        jsPaths = json.load(file)
    
    # Initialize an empty dictionary to store the new file paths
    file_paths_dict = {}

    # Process each component's JS relative path and store the new file path in the dictionary
    for component in jsPaths["components"]:
        name = component["name"]
        JsRelativePath = component["path"].strip('`')
        new_file_path = fileNavigator(FolderPathPython, JsRelativePath)
        new_file_path_with_extension = new_file_path + '.tsx'
        # Store in dictionary
        file_paths_dict[name] = new_file_path_with_extension

    return file_paths_dict

# Function to print the contents of each file path
def printFileContents(file_paths_dict):
    for component_name, file_path in file_paths_dict.items():
        if os.path.exists(file_path):
            with open(file_path, 'r') as file:
                content = file.read()
                print(f"Contents of {component_name} ({file_path}):\n{content}\n")
        else:
            print(f"File {file_path} does not exist.\n")

# Example usage
FolderPathPython = "C:\\Users\\DGASERLAP177\\Documents\\GitHub\\StocksGPT\\src\\pages\\Authentication"
jsonFilePath = "components_login.json"  # Assuming this file contains the JSON array of paths

# Process paths and store the result in a dictionary
result = processPathsFromJson(jsonFilePath, FolderPathPython)

# Print the result dictionary
print("Dictionary of new file paths:")
for key, value in result.items():
    print(f"{key}: {value}")

# Print the contents of each file path
printFileContents(result)
# Out:
# Dictionary of new file paths:
# **Loader**: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\Loader.tsx
# **AuthHeader**: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\AuthHeader.tsx
# **FormInput**: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\FormInput.tsx
# **NonAuthLayoutWrapper**: C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\NonAutnLayoutWrapper.tsx
# Contents of **Loader** (C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\Loader.tsx):
# import React from "react";
# import { Spinner } from "reactstrap";
#
# const Loader = () => {
#   return (
#     <div className="loader-container">
#       <div className="status">
#         <Spinner color="primary" />
#       </div>
#     </div>
#   );
# };
#
# export default Loader;
#
#
# Contents of **AuthHeader** (C:\Users\DGASERLAP177\Documents\GitHub\StocksGPT\src\components\AuthHeader.tsx):
# import React from "react";
#
# interface AuthHeaderProps {
# ...

# %%
child_response = chat.send_message('Find all the Components in the component import section of the above codes and write in key value pairs where keys are the component names and values are its exact source path:'+result)
child_component_path=child_response.text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 child_response = chat.send_message('Find all the Components in the component import section of the above codes and write in key value pairs where keys are the component names and values are its exact source path:'+result)
#       2 child_component_path=child_response.text
#
# TypeError: can only concatenate str (not "dict") to str

# %%
print(child_component_path)
# Out:
# - **NonAuthLayoutWrapper**: `../../components/NonAutnLayoutWrapper`
# - **AuthHeader**: `../../components/AuthHeader`
# - **FormInput**: `../../components/FormInput`
# - **Loader**: `../../components/Loader`
